# %% [markdown]
# # MTH229 blank notebook
# This uses Giac instead of SymPy and BinderPlots instead of Plots, but that shouldn't be noticeable

# %%
# run this cell to begin
using MTH229g
MTH229g.BinderPlots.PlotlyLight.settings.layout.width = 800
MTH229g.BinderPlots.PlotlyLight.settings.layout.height = 500;
